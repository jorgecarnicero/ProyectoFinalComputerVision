# %% [markdown]
# ## Camera Calibration Process:

# %% [markdown]
# ## 0. Preparation

# %%
import cv2
from typing import List
import numpy as np
import imageio
import cv2
import copy
import glob 
import matplotlib.pyplot as plt
import os
import json

# %%
# Auxiliar functions
def load_images(filenames: List) -> List:
    return [cv2.imread(filename) for filename in filenames]

def write_image(output_folder: str, img_name: str, img: np.array):
    img_path = os.path.join(output_folder, img_name)  
    os.makedirs(output_folder, exist_ok=True)
    cv2.imwrite(img_path, img)  

def show_image(img: np.array, img_name: str = "Image"):
    cv2.imshow(img_name, img)  
    cv2.waitKey(0) 
    cv2.destroyAllWindows()

# %% [markdown]
# ### Load the chessboard calibration images

# %%
imgs_gen_path = 'calibration_images/*.jpeg' 
imgs_path = sorted(glob.glob(imgs_gen_path))
imgs = load_images(imgs_path)  

imgs_path
# Out:
# ['calibration_images\\WhatsApp Image 2025-12-23 at 21.18.44.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.18.46.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.18.58.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.18.59 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.18.59.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.05 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.05 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.05 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.05 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.05 (5).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.05.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.06 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.06 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.06 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.06 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.06 (5).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.06.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.07 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.07 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.07 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.07 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.07 (5).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.07 (6).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.07.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08 (5).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08 (6).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08 (7).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.08.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.09 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.09 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.09 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.09 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.09 (5).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.09 (6).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.09.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.10 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.10 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.10 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.10 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.10.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.11 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.11 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.11 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.11 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.11 (5).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.11.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.12 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.12 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.12 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.12 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.12.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.13 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.13 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.13 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.13 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.13 (5).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.13.jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.14 (1).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.14 (2).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.14 (3).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.14 (4).jpeg',
#  'calibration_images\\WhatsApp Image 2025-12-23 at 21.19.14.jpeg']

# %%
len(imgs)
# Out:
# 66

# %% [markdown]
# ### Detect the corners of the pattern and refine them

# %%
# Number of rows and cols
pattern_size = (11,8)

# %%
corners = [cv2.findChessboardCorners(
    cv2.cvtColor(img, cv2.COLOR_RGB2GRAY), pattern_size) 
    for img in imgs]

# %%
len(corners)
# Out:
# 66

# %%
corners[1][1].shape
# Out:
# (88, 1, 2)

# %%
# Security copy
corners_copy = copy.deepcopy(corners)  

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.01) 

# To refine corner detections we input grayscale images
imgs_gray = [cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) for img in imgs]

corners_refined = [cv2.cornerSubPix(i, cor[1], pattern_size, (-1, -1), criteria) if cor[0] else [] for i, cor in zip(imgs_gray, corners_copy)]

# %%
corners_refined[12].shape
# Out:
# (88, 1, 2)

# %%
len(corners_refined)
# Out:
# 66

# %% [markdown]
# ### Check that the detection process was succesful drawing the detected corners

# %%
imgs_copy = copy.deepcopy(imgs)

# %%
output_folder_refined_corners = "refined_corners_output"

for i in range(len(corners_copy)):
    ret = corners_copy[i][0]
    if ret: 
        cv2.drawChessboardCorners(imgs_copy[i], pattern_size, corners_refined[i], ret) 
        #cv2.imshow(f"Img {i} and corners", imgs_copy[i]) 
        write_image(output_folder=output_folder_refined_corners, img_name=f"refined_corners_{i}.jpg", img=imgs_copy[i])
        cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
def get_chessboard_points(chessboard_shape, dx, dy):

    cols, rows = chessboard_shape 

    grid_xy = np.mgrid[0:cols, 0:rows].T.reshape(-1,2)

    objp = np.zeros([grid_xy.shape[0], 3], dtype=np.float32) 

    objp[:,0] = grid_xy[:,0]*dx  
    objp[:,1] = grid_xy[:,1]*dy  

    return objp

# %%
# Needs to be changed to the real position of our chessboard corners
dx, dy = 16, 16 
chessboard_points = [get_chessboard_points(pattern_size, dx, dy) for _ in corners_refined]

# %%
len(chessboard_points)
# Out:
# 66

# %%
chessboard_points[0]
# Out:
# array([[  0.,   0.,   0.],
#        [ 16.,   0.,   0.],
#        [ 32.,   0.,   0.],
#        [ 48.,   0.,   0.],
#        [ 64.,   0.,   0.],
#        [ 80.,   0.,   0.],
#        [ 96.,   0.,   0.],
#        [112.,   0.,   0.],
#        [128.,   0.,   0.],
#        [144.,   0.,   0.],
#        [160.,   0.,   0.],
#        [  0.,  16.,   0.],
#        [ 16.,  16.,   0.],
#        [ 32.,  16.,   0.],
#        [ 48.,  16.,   0.],
#        [ 64.,  16.,   0.],
#        [ 80.,  16.,   0.],
#        [ 96.,  16.,   0.],
#        [112.,  16.,   0.],
#        [128.,  16.,   0.],
#        [144.,  16.,   0.],
#        [160.,  16.,   0.],
#        [  0.,  32.,   0.],
#        [ 16.,  32.,   0.],
#        [ 32.,  32.,   0.],
#        [ 48.,  32.,   0.],
#        [ 64.,  32.,   0.],
#        [ 80.,  32.,   0.],
#        [ 96.,  32.,   0.],
#        [112.,  32.,   0.],
#        [128.,  32.,   0.],
#        [144.,  32.,   0.],
#        [160.,  32.,   0.],
#        [  0.,  48.,   0.],
#        [ 16.,  48.,   0.],
#        [ 32.,  48.,   0.],
#        [ 48.,  48.,   0.],
#        [ 64.,  48.,   0.],
#        [ 80.,  48.,   0.],
#        [ 96.,  48.,   0.],
#        [112.,  48.,   0.],
#        [128.,  48.,   0.],
#        [144.,  48.,   0.],
#        [160.,  48.,   0.],
#        [  0.,  64.,   0.],
#        [ 16.,  64.,   0.],
#        [ 32.,  64.,   0.],
#        [ 48.,  64.,   0.],
#        [ 64.,  64.,   0.],
#        [ 80.,  64.,   0.],
#        [ 96.,  64.,   0.],
#        [112.,  64.,   0.],
#        [128.,  64.,   0.],
#        [144.,  64.,   0.],
#        [160.,  64.,   0.],
#        [  0.,  80.,   0.],
#        [ 16.,  80.,   0.],
#        [ 32.,  80.,   0.],
#        [ 48.,  80.,   0.],
#        [ 64.,  80.,   0.],
#        [ 80.,  80.,   0.],
#        [ 96.,  80.,   0.],
#        [112.,  80.,   0.],
#        [128.,  80.,   0.],
#        [144.,  80.,   0.],
#        [160.,  80.,   0.],
#        [  0.,  96.,   0.],
#        [ 16.,  96.,   0.],
#        [ 32.,  96.,   0.],
#        [ 48.,  96.,   0.],
#        [ 64.,  96.,   0.],
#        [ 80.,  96.,   0.],
#        [ 96.,  96.,   0.],
#        [112.,  96.,   0.],
#        [128.,  96.,   0.],
#        [144.,  96.,   0.],
#        [160.,  96.,   0.],
#        [  0., 112.,   0.],
#        [ 16., 112.,   0.],
#        [ 32., 112.,   0.],
#        [ 48., 112.,   0.],
#        [ 64., 112.,   0.],
#        [ 80., 112.,   0.],
#        [ 96., 112.,   0.],
#        [112., 112.,   0.],
#        [128., 112.,   0.],
#        [144., 112.,   0.],
#        [160., 112.,   0.]], dtype=float32)

# %%
chessboard_points[0].shape
# Out:
# (88, 3)

# %% [markdown]
# ### Obtain the calibration parameters for our camera

# %%
# Filter data and get only those with adequate detections
valid_corners = [cor[1] for cor in corners if cor[0]]  

# Convert list to numpy array
valid_corners = np.asarray(valid_corners, dtype=np.float32)

# %%
valid_corners
# Out:
# array([[[[1342.0977 ,  766.6502 ]],
#
#         [[1298.2479 ,  780.3515 ]],
#
#         [[1254.0314 ,  794.20746]],
#
#         ...,
#
#         [[ 890.0215 ,  601.02826]],
#
#         [[ 846.84094,  615.8752 ]],
#
#         [[ 804.09436,  630.592  ]]],
#
#
#        [[[1368.2789 ,  794.3445 ]],
#
#         [[1322.1343 ,  809.29425]],
#
#         [[1276.2126 ,  824.76953]],
#
#         ...,
#
#         [[ 892.97284,  622.7591 ]],
#
#         [[ 849.4312 ,  638.8274 ]],
#
#         [[ 805.59546,  655.14484]]],
#
#
#        [[[1245.4803 ,  851.95294]],
#
#         [[1198.2872 ,  843.06476]],
#
#         [[1150.7062 ,  834.3657 ]],
#
#         ...,
#
#         [[ 922.5063 ,  459.92786]],
#
#         [[ 877.1082 ,  453.27664]],
#
#         [[ 831.44183,  446.0055 ]]],
#
#
#        ...,
#
#
#        [[[ 644.513  ,  678.4915 ]],
#
#         [[ 676.83154,  682.4856 ]],
#
#         [[ 709.21173,  685.7653 ]],
#
#         ...,
#
#         [[ 889.8174 ,  880.1773 ]],
#
#         [[ 923.1162 ,  883.66284]],
#
#         [[ 956.55054,  887.0669 ]]],
#
#
#        [[[ 663.5202 ,  671.585  ]],
#
#         [[ 695.2798 ,  676.18176]],
#
#         [[ 726.0345 ,  680.51135]],
#
#         ...,
#
#         [[ 894.8678 ,  880.32513]],
#
#         [[ 927.40405,  884.6111 ]],
#
#         [[ 960.13446,  888.81805]]],
#
#
#        [[[ 624.3194 ,  640.36676]],
#
#         [[ 657.77075,  641.7516 ]],
#
#         [[ 690.91394,  643.2345 ]],
#
#         ...,
#
#         [[ 924.91736,  761.8637 ]],
#
#         [[ 958.44495,  763.4623 ]],
#
#         [[ 991.55115,  764.4788 ]]]], dtype=float32)

# %%
chessboard_points[0].shape
# Out:
# (88, 3)

# %%
valid_corners[0].shape
# Out:
# (88, 1, 2)

# %%
len(valid_corners)
# Out:
# 64

# %%
len(chessboard_points)
# Out:
# 66

# %%
# We adjust the number of chessboard_points to be equal to the number of valid corners
chessboard_points = [chessboard_points[i] for i in range(len(valid_corners))]  
len(chessboard_points)
# Out:
# 64

# %%
img_size = (imgs_gray[0].shape[1], imgs_gray[0].shape[0]) 

rms, intrinsics, dist_coeffs, rvecs, tvecs = cv2.calibrateCamera(chessboard_points, valid_corners, img_size, None, None)

# Obtain extrinsics
extrinsics = list(map(lambda rvec, tvec: np.hstack((cv2.Rodrigues(rvec)[0], tvec)), rvecs, tvecs))

# %%
# Print outputs
print("Intrinsics:\n", intrinsics)
print("\nDistortion coefficients:\n", dist_coeffs)
print("\nRoot mean squared reprojection error:\n", rms)
print("\nExtrinsics:\n", extrinsics)
# Out:
# Intrinsics:
#  [[1.47708757e+03 0.00000000e+00 9.86469883e+02]
#  [0.00000000e+00 1.48148353e+03 6.72368302e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
#
# Distortion coefficients:
#  [[ 6.76789436e-02  5.27150448e-01 -3.06894709e-02  1.61476291e-03
#   -2.46949075e+00]]
#
# Root mean squared reprojection error:
#  1.6166388760877022
#
# Extrinsics:
#  [array([[-9.36630524e-01, -3.47985391e-01,  4.03661989e-02,
#          1.26204840e+02],
#        [ 3.09172806e-01, -8.75297031e-01, -3.71843089e-01,
#          3.42816169e+01],
#        [ 1.64728377e-01, -3.35799457e-01,  9.27417536e-01,
#          5.23598564e+02]]), array([[-9.29076695e-01, -3.63594134e-01,  6.79396786e-02,
#          1.28911319e+02],
#        [ 3.31423762e-01, -8.99859534e-01, -2.83568528e-01,
#          4.19454078e+01],
#        [ 1.64240021e-01, -2.40940087e-01,  9.56542257e-01,
#          4.98389977e+02]]), array([[-9.67655025e-01,  1.40252881e-01,  2.09697121e-01,
#          8.70014715e+01],
#        [-1.71363463e-01, -9.75445396e-01, -1.38350436e-01,
#          6.08033547e+01],
#        [ 1.85144044e-01, -1.69809920e-01,  9.67928858e-01,
#          4.94173212e+02]]), array([[-8.35776336e-01,  4.85270196e-01,  2.56886655e-01,
#          6.37709158e+01],
#        [-5.28455066e-01, -8.37925372e-01, -1.36441613e-01,
#          7.41394561e+01],
#        [ 1.49040798e-01, -2.49787726e-01,  9.56761691e-01,
#          5.32536848e+02]]), array([[-9.69980236e-01, -8.56640064e-02,  2.27596178e-01,
#          1.05201692e+02],
#        [ 5.59755480e-02, -9.89420212e-01, -1.33844621e-01,
#          7.03451795e+01],
#        [ 2.36653925e-01, -1.17086816e-01,  9.64513140e-01,
#          4.92934142e+02]]), array([[ 6.74224652e-01,  7.27195839e-01,  1.28869428e-01,
#         -9.69176321e+01],
#        [-5.89620698e-01,  6.35099839e-01, -4.98994616e-01,
#         -3.65345882e+01],
#        [-4.44711761e-01,  2.60450389e-01,  8.56969687e-01,
#          4.88332884e+02]]), array([[ 9.82435637e-05,  9.54791707e-01,  2.97275608e-01,
#         -3.92566645e+01],
#        [-8.92005156e-01,  1.34459743e-01, -4.31563877e-01,
#          1.38861110e+01],
#        [-4.52025212e-01, -2.65128977e-01,  8.51692335e-01,
#          5.26934532e+02]]), array([[-6.92261290e-01,  6.72378351e-01,  2.62071859e-01,
#          3.00571960e+01],
#        [-7.19007714e-01, -6.73670548e-01, -1.70868079e-01,
#          7.48110968e+01],
#        [ 6.16620954e-02, -3.06717045e-01,  9.49801264e-01,
#          5.51052563e+02]]), array([[ 9.29093772e-01,  3.37084970e-01,  1.52179122e-01,
#         -7.40325238e+01],
#        [-2.47577905e-01,  8.72532857e-01, -4.21178816e-01,
#         -1.06685548e+02],
#        [-2.74754332e-01,  3.53638426e-01,  8.94119634e-01,
#          4.03528064e+02]]), array([[ 5.01230430e-01,  8.54708769e-01, -1.35059158e-01,
#         -5.03863702e+01],
#        [-6.87806392e-01,  4.88235155e-01,  5.37167387e-01,
#          3.11370292e+00],
#        [ 5.25062305e-01, -1.76350088e-01,  8.32592471e-01,
#          3.55223809e+02]]), array([[-6.73205089e-01,  6.98325758e-01,  2.43179037e-01,
#          2.77892434e+01],
#        [-7.37233684e-01, -6.59325525e-01, -1.47568111e-01,
#          6.25422756e+01],
#        [ 5.72835333e-02, -2.78623381e-01,  9.58690570e-01,
#          5.33544598e+02]]), array([[ 3.99398230e-01,  9.16773433e-01,  2.74339384e-03,
#         -7.31465379e+01],
#        [-6.18245138e-01,  2.67130452e-01,  7.39198397e-01,
#          9.76453181e+01],
#        [ 6.76944608e-01, -2.96930621e-01,  6.73482148e-01,
#          3.70649750e+02]]), array([[ 4.10165179e-01,  9.06242359e-01,  1.02417344e-01,
#         -7.97391790e+01],
#        [-5.62955004e-01,  1.63229106e-01,  8.10208567e-01,
#          1.17236288e+02],
#        [ 7.17527832e-01, -3.89975699e-01,  5.77124566e-01,
#          3.51433097e+02]]), array([[ 5.87288070e-01,  7.80334923e-01,  2.14872358e-01,
#         -1.06761615e+02],
#        [-5.92046594e-01,  2.33157507e-01,  7.71439180e-01,
#          7.54815498e+01],
#        [ 5.51881829e-01, -5.80271475e-01,  5.98925256e-01,
#          3.91103672e+02]]), array([[ 9.21480828e-01,  3.43896878e-01,  1.80576913e-01,
#         -9.51940681e+01],
#        [-3.79550752e-01,  6.98408774e-01,  6.06767181e-01,
#          1.44887832e+02],
#        [ 8.25488390e-02, -6.27662427e-01,  7.74096613e-01,
#          6.05031939e+02]]), array([[ 9.52689424e-01,  3.03511083e-01, -1.62444893e-02,
#         -8.19104838e+01],
#        [-1.22601481e-01,  4.32638533e-01,  8.93192463e-01,
#          1.11468685e+02],
#        [ 2.78121804e-01, -8.48943415e-01,  4.49381063e-01,
#          4.54804127e+02]]), array([[ 8.83278924e-01,  4.58946554e-01,  9.58457289e-02,
#         -5.23428952e+01],
#        [-4.01900132e-01,  6.35889323e-01,  6.58878632e-01,
#          2.48338954e+01],
#        [ 2.41442802e-01, -6.20494020e-01,  7.46118318e-01,
#          3.88374880e+02]]), array([[ 8.22684733e-01,  5.66838226e-01,  4.34080103e-02,
#         -1.96039523e+01],
#        [-4.96365260e-01,  6.78979044e-01,  5.40933440e-01,
#          4.08969125e+01],
#        [ 2.77148622e-01, -4.66563911e-01,  8.39944497e-01,
#          3.93775451e+02]]), array([[ 9.17147921e-01,  3.79466113e-01,  1.21840719e-01,
#         -9.72215682e+01],
#        [-3.46481972e-01,  6.08086062e-01,  7.14269966e-01,
#          4.42911868e+01],
#        [ 1.96951605e-01, -6.97306826e-01,  6.89183035e-01,
#          4.34434953e+02]]), array([[ 6.80597957e-01,  6.74917177e-01,  2.85084593e-01,
#         -9.92322812e+01],
#        [-6.47887576e-01,  3.72736198e-01,  6.64311234e-01,
#          4.69202972e+01],
#        [ 3.42093715e-01, -6.36831635e-01,  6.90953948e-01,
#          4.03099151e+02]]), array([[ 9.74163194e-01,  2.22679527e-01, -3.76815656e-02,
#         -8.58319381e+01],
#        [-1.37664814e-01,  7.17748325e-01,  6.82558232e-01,
#          4.58513411e+01],
#        [ 1.79037625e-01, -6.59735681e-01,  7.29859137e-01,
#          4.64352860e+02]]), array([[ 9.71382480e-01,  2.32970806e-01, -4.62674883e-02,
#         -5.06095371e+01],
#        [-1.58770326e-01,  7.81760227e-01,  6.03028134e-01,
#          3.11103549e+01],
#        [ 1.76658033e-01, -5.78425061e-01,  7.96377039e-01,
#          6.17836490e+02]]), array([[ 9.21107815e-01,  3.89091725e-01, -1.29623563e-02,
#         -5.03776504e+01],
#        [-1.91076744e-01,  4.80849487e-01,  8.55729776e-01,
#          6.83936969e+01],
#        [ 3.39190317e-01, -7.85742579e-01,  5.17260600e-01,
#          4.17494934e+02]]), array([[ 8.50694514e-01,  5.24502876e-01,  3.48651235e-02,
#         -1.13872517e+02],
#        [-3.93939768e-01,  5.92208188e-01,  7.02923126e-01,
#          5.60503077e+01],
#        [ 3.48037790e-01, -6.11707606e-01,  7.10410798e-01,
#          9.72924259e+02]]), array([[ 9.72589570e-01,  2.29208601e-01,  3.91528606e-02,
#         -1.25294365e+02],
#        [-2.18029997e-01,  8.40400478e-01,  4.96175329e-01,
#          8.17659210e+01],
#        [ 8.08235700e-02, -4.91111447e-01,  8.67339090e-01,
#          1.02382737e+03]]), array([[-9.74350811e-01,  1.92306500e-01,  1.16870471e-01,
#          9.32346879e+01],
#        [-4.11487195e-02, -6.62842240e-01,  7.47627546e-01,
#          1.72872765e+02],
#        [ 2.21240321e-01,  7.23642436e-01,  6.53754040e-01,
#          1.02362896e+03]]), array([[-9.70632132e-01,  2.06900645e-01,  1.22741142e-01,
#          8.71750284e+01],
#        [-4.63330036e-02, -6.61439142e-01,  7.48566306e-01,
#          1.53031754e+02],
#        [ 2.36064647e-01,  7.20895544e-01,  6.51600412e-01,
#          1.02430131e+03]]), array([[-9.62988465e-01,  2.59206741e-01,  7.39261918e-02,
#          8.73827252e+01],
#        [-1.19844188e-01, -6.57410783e-01,  7.43941149e-01,
#          1.34263501e+02],
#        [ 2.41434436e-01,  7.07547120e-01,  6.64143422e-01,
#          1.01899422e+03]]), array([[-9.46647987e-01,  3.04397632e-01,  1.05828497e-01,
#          8.56747536e+01],
#        [-1.49125884e-01, -7.04868312e-01,  6.93485496e-01,
#          1.37215548e+02],
#        [ 2.85690497e-01,  6.40704880e-01,  7.12655735e-01,
#          1.02434420e+03]]), array([[-8.68285958e-01,  4.58261826e-01,  1.89935764e-01,
#          5.45704312e+01],
#        [-2.47747951e-01, -7.32315286e-01,  6.34299042e-01,
#          1.41978122e+02],
#        [ 4.29767900e-01,  5.03696755e-01,  7.49392508e-01,
#          1.00994811e+03]]), array([[ 8.44001552e-01,  5.35518719e-01,  2.96830099e-02,
#         -1.08710456e+02],
#        [-3.46361488e-01,  5.01953452e-01,  7.92512746e-01,
#          6.73693938e+01],
#        [ 4.09505922e-01, -6.79163039e-01,  6.09132553e-01,
#          9.54284780e+02]]), array([[-4.96174945e-01,  8.64659789e-01, -7.85739969e-02,
#         -5.54818092e+01],
#        [-7.33986377e-01, -3.69399400e-01,  5.69919364e-01,
#          2.06436602e+02],
#        [ 4.63761170e-01,  3.40451952e-01,  8.17935233e-01,
#          9.49483892e+02]]), array([[-4.57886493e-01,  8.85039493e-01, -8.39348346e-02,
#         -5.71579482e+01],
#        [-7.30497425e-01, -3.20754592e-01,  6.02901322e-01,
#          1.84281176e+02],
#        [ 5.06668996e-01,  3.37374552e-01,  7.93388265e-01,
#          9.51660629e+02]]), array([[-4.26625495e-01,  9.03696416e-01, -3.63795827e-02,
#         -7.50657506e+01],
#        [-6.27729048e-01, -2.66906985e-01,  7.31243396e-01,
#          2.50974062e+02],
#        [ 6.51112072e-01,  3.34803596e-01,  6.81145816e-01,
#          9.04099361e+02]]), array([[-9.73185565e-01,  2.15272011e-01, -8.10420765e-02,
#          4.78108171e+00],
#        [-2.15757872e-01, -7.32168508e-01,  6.46047844e-01,
#          1.91062753e+02],
#        [ 7.97395624e-02,  6.46209901e-01,  7.58982454e-01,
#          8.89300815e+02]]), array([[-8.93172940e-01,  4.29954888e-01, -1.31836614e-01,
#          9.08720902e+00],
#        [-4.18545669e-01, -6.87512344e-01,  5.93419161e-01,
#          2.17777693e+02],
#        [ 1.64504169e-01,  5.85205580e-01,  7.94023178e-01,
#          8.33628020e+02]]), array([[-5.04256816e-01,  8.60730742e-01, -6.97685664e-02,
#         -6.76483687e+01],
#        [-6.54341335e-01, -3.28119428e-01,  6.81303940e-01,
#          2.85511157e+02],
#        [ 5.63526824e-01,  3.89204612e-01,  7.28668161e-01,
#          8.88224896e+02]]), array([[-6.90019731e-01,  6.81261649e-01,  2.44449047e-01,
#          8.23302971e+00],
#        [-4.21540800e-01, -6.52802419e-01,  6.29406352e-01,
#          1.98694893e+02],
#        [ 5.88367338e-01,  3.31257555e-01,  7.37626130e-01,
#          9.79783049e+02]]), array([[-8.76432562e-01,  4.67428627e-01, -1.15656574e-01,
#         -1.28891341e+01],
#        [-4.04847492e-01, -5.85260856e-01,  7.02544119e-01,
#          2.95218669e+02],
#        [ 2.60699968e-01,  6.62555816e-01,  7.02178978e-01,
#          7.71297833e+02]]), array([[-9.67198194e-01,  8.88638634e-02, -2.37972407e-01,
#          2.98925682e+01],
#        [-2.06061220e-01, -8.22298761e-01,  5.30437104e-01,
#          1.86557733e+02],
#        [-1.48547725e-01,  5.62074694e-01,  8.13637273e-01,
#          7.19123475e+02]]), array([[-8.69465025e-01, -4.92985565e-01,  3.15563427e-02,
#          1.19640334e+02],
#        [ 4.64617260e-01, -7.94388333e-01,  3.91251809e-01,
#          8.83218248e+01],
#        [-1.67813504e-01,  3.54841385e-01,  9.19742475e-01,
#          6.88277449e+02]]), array([[-8.31743057e-01, -5.54879333e-01,  1.76752247e-02,
#          1.07794107e+02],
#        [ 4.44627310e-01, -6.46739251e-01,  6.19705492e-01,
#          1.18154067e+02],
#        [-3.32430509e-01,  5.23294628e-01,  7.84635386e-01,
#          6.98369593e+02]]), array([[-8.37083493e-01,  5.14318551e-01, -1.86460862e-01,
#         -1.35517314e+01],
#        [-5.00758213e-01, -5.83086729e-01,  6.39727347e-01,
#          2.59569747e+02],
#        [ 2.20300788e-01,  6.28877010e-01,  7.45641515e-01,
#          7.79496207e+02]]), array([[-9.33413873e-01, -3.56257158e-01,  4.26541745e-02,
#          1.16755188e+02],
#        [ 3.34992757e-01, -8.22712917e-01,  4.59263877e-01,
#          1.15040197e+02],
#        [-1.28523903e-01,  4.42972113e-01,  8.87275218e-01,
#          6.74084148e+02]]), array([[-8.07491447e-01, -5.73274747e-01,  1.38973476e-01,
#          9.67589572e+01],
#        [ 5.68690991e-01, -6.93995952e-01,  4.41542948e-01,
#          8.51342932e+01],
#        [-1.56678392e-01,  4.35575118e-01,  8.86411980e-01,
#          8.84222187e+02]]), array([[-9.15545281e-01, -3.83505311e-01,  1.21245677e-01,
#          1.07721553e+02],
#        [ 3.96475946e-01, -8.09760990e-01,  4.32543596e-01,
#          8.91553787e+01],
#        [-6.77027464e-02,  4.44084243e-01,  8.93423485e-01,
#          8.99131075e+02]]), array([[-9.50111967e-01, -2.19753800e-01,  2.21349312e-01,
#          6.16065224e+01],
#        [ 3.04120642e-01, -8.10277996e-01,  5.00959284e-01,
#          1.12476300e+02],
#        [ 6.92667706e-02,  5.43284306e-01,  8.36686487e-01,
#          8.55902860e+02]]), array([[-9.62242804e-01, -1.92704912e-01,  1.92233197e-01,
#          3.35770844e+01],
#        [ 2.72165239e-01, -6.91177881e-01,  6.69476825e-01,
#          1.46091336e+02],
#        [ 3.85586091e-03,  6.96518452e-01,  7.17528521e-01,
#          8.58449946e+02]]), array([[-8.19048534e-01, -5.73428226e-01,  1.84274030e-02,
#          1.06401125e+02],
#        [ 4.75666883e-01, -6.60753175e-01,  5.80642969e-01,
#          1.14173103e+02],
#        [-3.20781103e-01,  4.84340078e-01,  8.13949736e-01,
#          6.89817343e+02]]), array([[-9.64421783e-01,  2.47617211e-01, -9.26085415e-02,
#         -2.82967701e+01],
#        [-1.97401406e-01, -4.41485361e-01,  8.75284731e-01,
#          2.06563995e+02],
#        [ 1.75850248e-01,  8.62424717e-01,  4.74658085e-01,
#          8.43903478e+02]]), array([[-9.32348156e-01,  3.11509030e-01, -1.83545745e-01,
#         -3.61396990e+01],
#        [-3.27350759e-01, -5.11724217e-01,  7.94342374e-01,
#          1.94405362e+02],
#        [ 1.53520020e-01,  8.00687486e-01,  5.79077847e-01,
#          8.20728815e+02]]), array([[-9.50417107e-01,  2.58931024e-01, -1.72226735e-01,
#         -5.94131528e+00],
#        [-3.09202682e-01, -7.27738870e-01,  6.12200816e-01,
#          1.71038416e+02],
#        [ 3.31816947e-02,  6.35099096e-01,  7.71717638e-01,
#          8.08081775e+02]]), array([[-9.85179494e-01,  1.30917107e-01, -1.10824530e-01,
#          1.36923744e+01],
#        [-1.70853483e-01, -6.91801797e-01,  7.01583467e-01,
#          2.03777399e+02],
#        [ 1.51806690e-02,  7.10120402e-01,  7.03916587e-01,
#          8.03128016e+02]]), array([[-9.89896735e-01,  6.29911027e-02,  1.27029820e-01,
#         -2.62791343e+00],
#        [ 5.10194572e-02, -6.77654247e-01,  7.33608708e-01,
#          1.88509021e+02],
#        [ 1.32293119e-01,  7.32677857e-01,  6.67593955e-01,
#          8.60259027e+02]]), array([[-9.39692284e-01, -3.41072277e-01, -2.54580827e-02,
#          1.39559346e+02],
#        [ 2.08972662e-01, -6.31477986e-01,  7.46703408e-01,
#          1.13945513e+02],
#        [-2.70756051e-01,  6.96351387e-01,  6.64669773e-01,
#          7.31065546e+02]]), array([[ 5.61381621e-01, -8.25300208e-01, -6.10757118e-02,
#         -1.12742876e+02],
#        [ 4.35102453e-01,  2.31572750e-01,  8.70091902e-01,
#         -8.70470919e+00],
#        [-7.03943556e-01, -5.15027794e-01,  4.89090830e-01,
#          8.20250943e+02]]), array([[ 7.43813681e-01, -6.64884631e-01, -6.83347377e-02,
#         -1.03443605e+02],
#        [ 3.54587405e-01,  3.05869348e-01,  8.83578924e-01,
#          3.08647282e+00],
#        [-5.66576545e-01, -6.81448729e-01,  4.63269521e-01,
#          8.07348307e+02]]), array([[ 9.20095744e-01, -3.78326788e-01, -1.01452763e-01,
#         -1.32571781e+02],
#        [ 2.75653721e-01,  4.41405300e-01,  8.53918256e-01,
#         -1.90538258e+01],
#        [-2.78278364e-01, -8.13652384e-01,  5.10422325e-01,
#          7.55740675e+02]]), array([[ 9.85438507e-01, -9.78587587e-02, -1.39048956e-01,
#         -1.58945515e+02],
#        [ 1.67789469e-01,  4.27284795e-01,  8.88411165e-01,
#         -1.87804545e+00],
#        [-2.75253093e-02, -8.98805523e-01,  4.37482559e-01,
#          7.48466430e+02]]), array([[-9.33852632e-01, -3.54163916e-01, -4.98716502e-02,
#          9.81211628e+01],
#        [ 2.10762632e-01, -6.57586157e-01,  7.23297698e-01,
#          1.40850304e+02],
#        [-2.88960852e-01,  6.64942379e-01,  6.88733082e-01,
#          6.64734910e+02]]), array([[ 9.16275888e-01,  3.22281182e-01, -2.37851503e-01,
#         -1.76772125e+02],
#        [ 4.82450944e-02,  5.00693897e-01,  8.64278909e-01,
#          1.71974683e+01],
#        [ 3.97631625e-01, -8.03393092e-01,  4.43225259e-01,
#          7.34194605e+02]]), array([[ 9.83586016e-01,  1.28368508e-02, -1.79982678e-01,
#         -1.73130000e+02],
#        [ 1.19949563e-01,  6.98646143e-01,  7.05340817e-01,
#          3.84684664e+00],
#        [ 1.34798559e-01, -7.15352208e-01,  6.85638802e-01,
#          7.49929563e+02]]), array([[ 9.81882267e-01, -2.46686447e-02, -1.87879405e-01,
#         -1.67523051e+02],
#        [ 1.47086300e-01,  7.24323515e-01,  6.73588202e-01,
#          2.13821248e-01],
#        [ 1.19468963e-01, -6.89018798e-01,  7.14828835e-01,
#          7.68032549e+02]]), array([[ 9.53632535e-01,  2.45640934e-01, -1.73912392e-01,
#         -1.77930804e+02],
#        [ 4.92857053e-02,  4.42581042e-01,  8.95373073e-01,
#         -1.51470970e+01],
#        [ 2.96910606e-01, -8.62428288e-01,  4.09953094e-01,
#          7.28650974e+02]])]

# %%
def save_calibration_data(mtx, dist, rvecs, tvecs, filename="calibration_data.json"):
    """
    Saves the intrinsic matrix, distortion coefficients, and extrinsic parameters
    (rvecs, tvecs) to a JSON file.
    """
    print("Saving calibration data...")
    
    # Convert NumPy arrays to standard Python lists
    if isinstance(mtx, np.ndarray):
        mtx_list = mtx.tolist()
    else:
        mtx_list = mtx

    if isinstance(dist, np.ndarray):
        # Flatten the distortion coefficients array before converting
        dist_list = np.ravel(dist).tolist() 
    else:
        dist_list = dist

    # Process Extrinsics (rvecs and tvecs are lists of arrays)
    # Convert each array within the list to a Python list
    rvecs_list = []
    if rvecs is not None:
        for r in rvecs:
            if isinstance(r, np.ndarray):
                rvecs_list.append(r.tolist())
            else:
                rvecs_list.append(r)

    tvecs_list = []
    if tvecs is not None:
        for t in tvecs:
            if isinstance(t, np.ndarray):
                tvecs_list.append(t.tolist())
            else:
                tvecs_list.append(t)

    # Create the data dictionary
    data = {
        "intrinsics": mtx_list,
        "distortion": dist_list,
        "extrinsics": {
            "rvecs": rvecs_list,
            "tvecs": tvecs_list
        }
    }

    # Write to file
    try:
        with open(filename, 'w') as f:
            json.dump(data, f, indent=4)
        print(f"Success! Data saved to '{filename}'")
        print(f"   Matrix: \n{np.array(mtx_list)}")
        print(f"   Distortion: {dist_list}")
        print(f"   Extrinsics saved: {len(rvecs_list)} vector pairs.")
    except Exception as e:
        print(f"Error saving the file: {e}")

if 'intrinsics' in locals() and 'dist_coeffs' in locals() and 'rvecs' in locals() and 'tvecs' in locals():
    save_calibration_data(intrinsics, dist_coeffs, rvecs, tvecs)
else:
    print("Saving error: Required calibration variables not found in local scope.")
# Out:
# Saving calibration data...
# Success! Data saved to 'calibration_data.json'
#    Matrix:
# [[1.47708757e+03 0.00000000e+00 9.86469883e+02]
#  [0.00000000e+00 1.48148353e+03 6.72368302e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
#    Distortion: [0.06767894363427608, 0.5271504479204613, -0.0306894708863236, 0.001614762907429389, -2.4694907498437453]
#    Extrinsics saved: 64 vector pairs.
